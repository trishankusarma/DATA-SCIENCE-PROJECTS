# %% [markdown]
# Answer to question 1:
#
# **Basic Data Types of Python:**
#
# 1.Numeric :
# In Python, numeric data type represent the data which has numeric value. Numeric value can be integer, floating number or even complex numbers. These values are defined as int, float and complex class in Python.
#
# 2.Sequence Type:
# In Python, sequence is the ordered collection of similar or different data types. Sequences allows to store multiple values in an organized and efficient fashion. There are several sequence types in Python –
#   String
#   List
#   Tuple
#
# 3.Boolean:
# Data type with one of the two built-in values, True or False. It is denoted by the class bool.
#
# 4.Set:
# In Python, Set is an unordered collection of data type that is iterable, mutable and has no duplicate elements. The order of elements in a set is undefined though it may consist of various elements.

# %% [markdown]
# Answer to question 2:
#
#     **If statements**                                          **for loops**
#
# 1.These are conditional statements                          1. These are iterative statements that runs some instructions inside
# that runs the furthur instructions based on                  it until the condition is true.
# when the condition is true.
#
# 2. syntax::                                                 2.  syntax::
#     if(condition)                                             for(initialization ; condition ; modifier)
#        //statements                                               //statements
#     else
#       //another stements

# %% [markdown]
# Answer to question 9:

# %%
import numpy as np

# %%
def getNRandomInt(n,N):
    A = np.random.randint(N, size=(n));
    return A;
    
X=getNRandomInt(100,10)

print("Random array of 100 numbers with random elements within the range of 0 to 10\n")

print(X)
# Out:
# Random array of 100 numbers with random elements within the range of 0 to 10
#
# [6 9 5 6 3 1 2 9 1 9 4 2 8 7 4 3 8 0 2 6 3 7 1 1 1 9 0 5 4 8 4 1 1 6 0 5 8
#  8 0 6 3 0 5 6 4 6 6 0 0 7 6 8 4 6 5 9 2 5 5 1 9 6 6 9 5 8 2 0 3 9 8 0 5 6
#  5 0 8 0 3 7 5 1 5 3 0 1 4 9 8 2 3 3 5 1 8 3 1 7 4 0]

# %%
min = np.min(X)
print("Minimum value:\n",min)
# Out:
# Minimum value:
#  0

# %%
max = np.max(X)
print("Maximum value:\n",max)
# Out:
# Maximum value:
#  9

# %%
avg = np.mean(X)
print("The average value is :\n",avg)
# Out:
# The average value is :
#  4.33

# %%
unique_elements , counts_elements = np.unique( X , return_counts = True)

print("Frequency of unique values of the said array is :\n")

for x in unique_elements :
    print(" Element ", x ," : Frquency ", counts_elements[x])
# Out:
# Frequency of unique values of the said array is :
#
#  Element  0  : Frquency  13
#  Element  1  : Frquency  12
#  Element  2  : Frquency  6
#  Element  3  : Frquency  10
#  Element  4  : Frquency  8
#  Element  5  : Frquency  13
#  Element  6  : Frquency  13
#  Element  7  : Frquency  5
#  Element  8  : Frquency  11
#  Element  9  : Frquency  9

# %%
from matplotlib import pyplot as plt

#plotting to our canvas
plt.bar(unique_elements , counts_elements )

plt.title("Frequency distribution")
plt.xlabel("Numbers")
plt.ylabel("Frequency of the numbers")

#frequency distribution table
plt.show()

# %% [markdown]
# **Answer to question 7**

# %%
import numpy as  np
import math
from matplotlib import pyplot as plt

def plotValue(c,k):
    powV = np.power(c,k);
    expV = np.exp(-c);
    factV = math.factorial(k);
    return (powV*expV)/factV;

# %%
kArray = np.arange(51);
functionArray = np.empty(51);

for x in kArray :
    functionArray[x] = plotValue(1,x);

plt.plot( kArray , functionArray );

plt.title("Function F(k)=(C^k * e^-C)/(k!) Where C is a constant, k is a positive integer, e is euler’s constant. C : 1 ");
plt.xlabel("k - value");
plt.ylabel("function value for corresponding value of k");

plt.show();

# %%
kArray = np.arange(51);
functionArray = np.empty(51);

for x in kArray :
    functionArray[x] = plotValue(2.5,x);

plt.plot( kArray , functionArray );

plt.title("Function F(k)=(C^k * e^-C)/(k!) Where C is a constant, k is a positive integer, e is euler’s constant. C : 2.5 ");
plt.xlabel("k - value");
plt.ylabel("function value for corresponding value of k");

plt.show();

# %%
kArray = np.arange(51);
functionArray = np.empty(51);

for x in kArray :
    functionArray[x] = plotValue(7.8,x);

plt.plot( kArray , functionArray );

plt.title("Function F(k)=(C^k * e^-C)/(k!) Where C is a constant, k is a positive integer, e is euler’s constant. C : 7.8 ");
plt.xlabel("k - value");
plt.ylabel("function value for corresponding value of k");

plt.show();

# %% [markdown]
# **Answer to question 8**

# %%
import numpy as np;
import math;
from matplotlib import pyplot as plt;

position=0;
i=0;

#Array with values from -100 to 100
arr = np.linspace(-100,100,201);

#create an array to store the value of the occurence of a particular position
freq = np.zeros(201, dtype = int);
#-100 to 100 

freq[100]=1;
#As 0 is the initial position

print("For the sake of understanding we assume on a random trail, x=0 meaning a tail and so position shift to left by 1 and x=1 means head and position shift to right by 1\n")

while i<1000:
    x=math.floor(np.random.rand()*2)
    if x==0:
        position-=1;
    else:
        position+=1;
    freq[position+100]+=1
    i+=1

plt.plot(arr,freq);

plt.title("e frequencies against each cell value using matplotlib")
plt.xlabel("cell values")
plt.ylabel("Frequencies of occurence of each cell")

plt.show()
# Out:
# For the sake of understanding we assume on a random trail, x=0 meaning a tail and so position shift to left by 1 and x=1 means head and position shift to right by 1

# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import numpy as np;
import math;
from matplotlib import pyplot as plt;

position=0;
i=0;

#Array with values from -100 to 100
arr = np.linspace(-100,100,201);

#create an array to store the value of the occurence of a particular position
freq = np.zeros(201, dtype = int);
#-100 to 100 

freq[100]=1;
#As 0 is the initial position

print("For the sake of understanding we assume on a random trail, x=0 meaning a tail and so position shift to left by 1 and x=1 means head and position shift to right by 1\n")

while i<1000:
    import random
    coin= ['tail','head']
    x=random.choice(coin)
    if x=='tail':
        position-=1;
    else:
        position+=1;
    freq[position+100]+=1
    i+=1

plt.plot(arr,freq);
plt.xlabel("cell values")
plt.ylabel("Frequencies of occurence of each cell")

plt.show()
# Out:
# For the sake of understanding we assume on a random trail, x=0 meaning a tail and so position shift to left by 1 and x=1 means head and position shift to right by 1

# %% [markdown]
# **Answer to question 3**
#
# WAP to declare a blank list. Using loop (for/while your choice) append 10 random
# numbers to the list. Display the content of the list.

# %%
# creating a blank list
import random;
import math;

list = [];

#appending 10 random numbers to the list
i=0;
while i<10 :
    n = math.floor(random.random()*100);
    list.append(n);
    i+=1;

#display contents of list

for x in list:
    print(x)
# Out:
# 3
# 58
# 96
# 42
# 81
# 39
# 39
# 48
# 98
# 50

# %% [markdown]
# **Question 10**
#
# You are given a csv file that contains the readings of an experiment in each line. The
# First line of the file represents the column headers of the file. The first column
# represents just the serial number. The last column represents the type of object on
# which the experiment is performed. Your task is
# > Read the csv file using pandas library function
# > Determine how many distinct types of objects are there
# > Visualise the objects by plotting them in a 2-d plane. Since for each object you have
# four data columns, choose any two columns as the x and y coordinates while visualising.
# Different types of objects should be represented in different colors and preferably with
# different markers.
# (* the csv file will be provided as an extra document)

# %%
import pandas as pd;

# %%
df = pd.read_csv(r'C:\Users\TRISHANKU\Downloads\iris.csv')

df = df.drop('slno',axis=1)

# %%
print(df)
# Out:
#      petal length  petal width  sepal length  sepal width  species
# 0             1.4          0.2           5.1          3.5        0
# 1             1.4          0.2           4.9          3.0        0
# 2             1.3          0.2           4.7          3.2        0
# 3             1.5          0.2           4.6          3.1        0
# 4             1.4          0.2           5.0          3.6        0
# ..            ...          ...           ...          ...      ...
# 145           5.2          2.3           6.7          3.0        2
# 146           5.0          1.9           6.3          2.5        2
# 147           5.2          2.0           6.5          3.0        2
# 148           5.4          2.3           6.2          3.4        2
# 149           5.1          1.8           5.9          3.0        2
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: species, dtype: int64

# %%
from matplotlib import pyplot as plt;

plt.plot( df['petal length'] , df['petal width'] )

plt.title('petal length v/s petal width')
plt.xlabel('petal length')
plt.ylabel('petal width')

plt.show()

# %%
from matplotlib import pyplot as plt;

plt.plot( df['sepal length'] , df['sepal width'] )

plt.title('sepal length v/s sepal width')
plt.xlabel('sepal length')
plt.ylabel('sepal width')

plt.show()

# %%
from matplotlib import pyplot as plt;

plt.plot( df['petal length'] , df['species'] )

plt.title('petal length v/s species')
plt.xlabel('petal length')
plt.ylabel('species')

plt.show()

# %%
from matplotlib import pyplot as plt;

plt.plot( df['species'] , df['petal length'] )

plt.title('species v/s petal length')
plt.xlabel('species')
plt.ylabel('petal length')

plt.show()

# %%
df['species'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
print(df['petal length'].unique())
df['petal length'].unique().shape
# Out:
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
# (43,)

# %%
print(df['petal width'].unique())
df['petal width'].unique().shape
# Out:
# [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
# (22,)

# %%
print(df['sepal width'].unique())
df['sepal width'].unique().shape
# Out:
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
# (23,)

# %%
print(df['sepal length'].unique())
df['sepal length'].unique().shape
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
# (35,)

# %%
from matplotlib import pyplot as plt;

df.plot( x='species' ,y=['petal length','sepal length'] )

plt.title('species v/s petal length and sepal length')
plt.xlabel('species')

plt.show()

# %%
from matplotlib import pyplot as plt;

df.plot( x='species' ,y=['petal width','sepal width'] )

plt.title('species v/s petal width and sepal width')
plt.xlabel('species')

plt.show()

# %%
from matplotlib import pyplot as plt;

df.plot( x='species' ,y=['petal width','petal length'] )

plt.title('species v/s petal width and sepal width')
plt.xlabel('species')

plt.show()
